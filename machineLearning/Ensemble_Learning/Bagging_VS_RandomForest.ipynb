# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import plot_tree

# %%
X, y = make_classification(n_features=5, n_redundant=0, n_informative=5, n_clusters_per_class=1)

# %%
X
# Out:
# array([[-1.43904265, -1.72316918,  1.58256316, -2.78834273,  0.17956949],
#        [ 1.3587609 ,  0.38558534, -0.42099545,  2.09234741,  1.08016193],
#        [-0.99919694,  1.81215718,  1.51592471,  2.49581628,  0.42068039],
#        [-0.70812004, -1.36911462,  0.52988548, -0.31534918,  3.08002168],
#        [ 1.75246384,  1.06717068,  0.63021346,  1.73103863,  0.19182093],
#        [-1.40634963,  0.33557962,  1.44579076,  0.02121447,  0.66789135],
#        [-0.62996097,  2.30015471,  0.77902479,  0.53909176,  1.72506794],
#        [-0.68175674,  6.17129622, -1.4252381 ,  0.87456307,  3.31893448],
#        [ 0.54768048,  1.06483076,  1.90864786,  0.09796006,  1.67911316],
#        [ 0.91839607,  0.96048655, -0.96327514,  2.82953866,  1.00013993],
#        [-2.06795116,  0.29931562,  0.38852945, -0.97498167,  1.24793532],
#        [ 4.55231394,  5.18627831,  3.75411046,  1.33080168, -2.66210354],
#        [-1.95844438,  1.22625482, -1.08967833, -1.22894006,  2.76403704],
#        [-1.94625421,  0.92854707, -1.08019122, -1.82954566,  3.0455795 ],
#        [-0.90621242,  2.90774746,  0.7972806 ,  0.50870496,  1.34291111],
#        [-0.53467519,  0.53231067,  0.95491142, -0.53735823,  1.33312042],
#        [-1.93096466,  1.19550978, -0.37079503, -2.31656439,  2.21309851],
#        [-0.43711419, -0.10119584,  2.40321715,  0.0456055 ,  1.3059998 ],
#        [-0.52027996,  0.32968335, -0.34422211,  3.38749311,  0.06092986],
#        [-0.78191616, -0.66503789,  2.20706498, -2.20632706, -0.29103297],
#        [ 2.42345013,  1.97269316,  1.38897525, -0.03777588,  0.87012738],
#        [ 2.59074642,  2.25158881,  1.30648799,  0.90035367,  0.27651969],
#        [-0.62979493,  0.7765792 ,  1.09476932,  0.96168518,  1.90791133],
#        [-0.39373724,  2.09078111,  1.67637175, -1.87637405,  0.03146284],
#        [-1.11469114,  1.15574349,  1.07402121,  0.14270655,  1.10938547],
#        [ 0.15793704,  2.69073352,  1.45227952,  2.38991102, -0.20150448],
#        [-0.64104823, -0.5559978 ,  1.78593408, -3.05325129,  0.25403754],
#        [ 2.14731145,  0.65970557,  0.02517115,  0.77508078,  1.85976192],
#        [-1.46411362,  0.15669669,  0.58978671,  1.65281955,  1.42495663],
#        [ 1.14815885, -0.01801795,  2.0356759 , -0.56557711,  1.26793535],
#        [ 0.96573707,  1.46887241,  0.6151266 ,  2.44009966, -0.54531556],
#        [-0.0270012 ,  1.22560022,  2.15816545, -1.27683535,  0.0854471 ],
#        [-1.17460079,  1.7340261 , -0.65973105, -2.14266935,  2.5490377 ],
#        [-1.46317129,  0.59351824,  0.51292409, -1.65571808,  1.30351707],
#        [-1.72509873, -0.44563782,  1.23114112, -3.58089132,  0.13587714],
#        [ 0.45364606,  2.54906476,  2.13963078,  2.61609705, -0.93564042],
#        [-0.34872273,  1.42736486,  2.68545608, -0.15961698, -0.30889511],
#        [-1.9334552 ,  1.40191074, -0.51350898, -2.10037904,  1.88360917],
#        [-2.00639101,  3.80658586, -2.20949206, -0.64443444,  3.87513727],
#        [ 1.72811381,  2.6823062 ,  1.09531986,  1.90994437, -0.12842567],
#        [ 1.0055228 , -1.53794862,  0.47467166, -0.67071029,  3.39657971],
#        [-1.09402684,  0.01741347,  0.79996479,  2.36676332,  0.50866516],
#        [-0.45407176,  1.54121003,  1.38956832, -2.17824149,  0.68569771],
#        [-0.46038974, -0.4374312 ,  2.54970192, -1.72358356, -0.35236154],
#        [-0.39035171,  1.54039064,  1.5001316 , -0.81600199,  0.70791755],
#        [-0.50856674,  3.69476804,  0.73198682, -1.68901591,  0.98908736],
#        [-1.37611219, -0.05638993,  1.73051005, -2.48512664,  0.08885513],
#        [ 1.45870125, -0.1348011 ,  0.19763511,  0.11302178,  2.48313837],
#        [ 0.06632172,  0.47947171,  0.93099207,  1.34244777,  0.66960118],
#        [-1.00424997,  2.27471876,  0.7298995 , -0.21272446,  1.37513775],
#        [-1.43576425, -0.00823633,  0.85165112, -0.4978089 ,  1.15685288],
#        [-0.2804705 , -0.24926147, -0.09609698,  1.92623676,  1.43718109],
#        [ 0.85905264,  0.8486407 ,  1.37741889,  0.15901743,  1.88490651],
#        [-1.90653422, -1.73313902,  2.17166042, -4.38498691, -0.63477321],
#        [ 2.49441551,  1.82016106, -0.1284304 ,  1.95512707,  0.19030077],
#        [-2.23922357, -0.01925305, -0.88135489, -1.28793647,  2.83804418],
#        [-0.18418275,  0.69580631,  0.62238206,  2.91927624, -0.49576871],
#        [-0.51745789,  1.43466355,  1.53232555,  0.80876408,  0.74162621],
#        [ 3.07697574,  2.73353418,  1.85415674,  1.70743048, -1.01932963],
#        [-0.98610333,  0.80094728,  0.20935285,  1.79508136,  1.58948338],
#        [-0.84759702, -0.15955476,  2.40810511, -1.41710291, -0.42990619],
#        [-1.2233469 ,  1.41762981,  0.25553394, -0.66793597,  1.69375458]])

# %%
df = pd.DataFrame(X, columns=['col1', 'col2', 'col3', 'col4', 'col5'])
df['target'] = y

# %%
df.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0 -1.439043 -1.723169  1.582563 -2.788343  0.179569       0
# 1  1.358761  0.385585 -0.420995  2.092347  1.080162       1
# 2 -0.999197  1.812157  1.515925  2.495816  0.420680       1
# 3 -0.708120 -1.369115  0.529885 -0.315349  3.080022       1
# 4  1.752464  1.067171  0.630213  1.731039  0.191821       1

# %%
len(df)
# Out:
# 100

# %%
bag = BaggingClassifier(max_features=2)
bag.fit(df.iloc[:,:5], df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)
rf.fit(df.iloc[:,:5], df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(rf.estimators_[0])
plt.show()
